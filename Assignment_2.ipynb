# %% [markdown]
# # IEORE4004: OPTIMIZATION MODELS AND METHODS
# ### Created by Rodrigo Rojas
#
# # Formulation and solution with Gurobi of Assignment 1

# %% [markdown]
# Problem 7) A)

# %%
# Gurobipy is a library for mathematical programming available for Python
# More info in: https://www.gurobi.com/documentation/current/refman/py_python_api_overview.html


# We can install a free limited version on Collab with the following command

# !pip install gurobipy
import numpy as np
import gurobipy as gp
from gurobipy import GRB
# Out:
# Requirement already satisfied: gurobipy in /usr/local/lib/python3.10/dist-packages (11.0.3)

# %%
n=10
m=20
repeat = 50
solutions = []
for _ in range(repeat):
  model = gp.Model("Assignment Game")
  S = np.random.randint(1, 100, size=(n, m))
  x = model.addVars(n, m, vtype=GRB.BINARY, name="x")
  model.setObjective(gp.quicksum(S[i, j] * x[i, j] for i in range(n) for j in range(m)), GRB.MAXIMIZE)
  model.addConstrs((gp.quicksum(x[i, j] for j in range(m)) <= 1 for i in range(n)), name="BuyerConstraint")
  model.addConstrs((gp.quicksum(x[i, j] for i in range(n)) <= 1 for j in range(m)), name="SellerConstraint")
  model.optimize()
  if model.status == GRB.OPTIMAL:
        for i in range(n):
            for j in range(m):
                if x[i, j].x == 1:  # If buyer i is assigned to seller j
                    solutions.append((i, j, S[i, j]))
                    print(f"Buyer {i+1} is assigned to Seller {j+1} with value {S[i, j]}")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xfb9d716a
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 555.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 935.0000000
#
# Root relaxation: objective 9.520000e+02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     952.0000000  952.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 952 935 555
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.520000000000e+02, best bound 9.520000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 7 with value 98
# Buyer 2 is assigned to Seller 1 with value 98
# Buyer 3 is assigned to Seller 12 with value 94
# Buyer 4 is assigned to Seller 13 with value 99
# Buyer 5 is assigned to Seller 20 with value 98
# Buyer 6 is assigned to Seller 14 with value 87
# Buyer 7 is assigned to Seller 8 with value 96
# Buyer 8 is assigned to Seller 3 with value 88
# Buyer 9 is assigned to Seller 6 with value 99
# Buyer 10 is assigned to Seller 10 with value 95
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x78f3c409
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 548.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 868.0000000
#
# Root relaxation: objective 9.490000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     949.0000000  949.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 949 868 548
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.490000000000e+02, best bound 9.490000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 13 with value 96
# Buyer 2 is assigned to Seller 17 with value 95
# Buyer 3 is assigned to Seller 16 with value 97
# Buyer 4 is assigned to Seller 20 with value 94
# Buyer 5 is assigned to Seller 2 with value 99
# Buyer 6 is assigned to Seller 1 with value 81
# Buyer 7 is assigned to Seller 6 with value 94
# Buyer 8 is assigned to Seller 14 with value 99
# Buyer 9 is assigned to Seller 15 with value 96
# Buyer 10 is assigned to Seller 18 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x5ef1def6
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 408.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 929.0000000
#
# Root relaxation: objective 9.360000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     936.0000000  936.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 936 929 408
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.360000000000e+02, best bound 9.360000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 15 with value 85
# Buyer 2 is assigned to Seller 3 with value 97
# Buyer 3 is assigned to Seller 5 with value 93
# Buyer 4 is assigned to Seller 18 with value 98
# Buyer 5 is assigned to Seller 19 with value 98
# Buyer 6 is assigned to Seller 16 with value 93
# Buyer 7 is assigned to Seller 14 with value 96
# Buyer 8 is assigned to Seller 11 with value 91
# Buyer 9 is assigned to Seller 8 with value 89
# Buyer 10 is assigned to Seller 10 with value 96
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x47695ea8
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 633.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 929.0000000
#
# Root relaxation: objective 9.540000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     954.0000000  954.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 954 929 633
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.540000000000e+02, best bound 9.540000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 3 with value 91
# Buyer 2 is assigned to Seller 1 with value 96
# Buyer 3 is assigned to Seller 5 with value 95
# Buyer 4 is assigned to Seller 11 with value 95
# Buyer 5 is assigned to Seller 4 with value 93
# Buyer 6 is assigned to Seller 10 with value 99
# Buyer 7 is assigned to Seller 6 with value 96
# Buyer 8 is assigned to Seller 16 with value 98
# Buyer 9 is assigned to Seller 15 with value 93
# Buyer 10 is assigned to Seller 17 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xff436528
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 350.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 913.0000000
#
# Root relaxation: objective 9.430000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     943.0000000  943.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 943 913 350
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.430000000000e+02, best bound 9.430000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 8 with value 83
# Buyer 2 is assigned to Seller 12 with value 98
# Buyer 3 is assigned to Seller 19 with value 96
# Buyer 4 is assigned to Seller 10 with value 97
# Buyer 5 is assigned to Seller 1 with value 91
# Buyer 6 is assigned to Seller 13 with value 97
# Buyer 7 is assigned to Seller 16 with value 98
# Buyer 8 is assigned to Seller 20 with value 95
# Buyer 9 is assigned to Seller 11 with value 93
# Buyer 10 is assigned to Seller 14 with value 95
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x968eeeac
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 652.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 940.0000000
#
# Root relaxation: objective 9.630000e+02, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     963.0000000  963.00000  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 963 940 652
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.630000000000e+02, best bound 9.630000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 3 with value 97
# Buyer 2 is assigned to Seller 13 with value 99
# Buyer 3 is assigned to Seller 5 with value 97
# Buyer 4 is assigned to Seller 6 with value 84
# Buyer 5 is assigned to Seller 19 with value 99
# Buyer 6 is assigned to Seller 1 with value 97
# Buyer 7 is assigned to Seller 18 with value 97
# Buyer 8 is assigned to Seller 2 with value 99
# Buyer 9 is assigned to Seller 8 with value 98
# Buyer 10 is assigned to Seller 15 with value 96
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x51fc9475
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 595.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 922.0000000
#
# Root relaxation: objective 9.280000e+02, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     928.0000000  928.00000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 928 922 595
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.280000000000e+02, best bound 9.280000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 1 with value 98
# Buyer 2 is assigned to Seller 19 with value 98
# Buyer 3 is assigned to Seller 17 with value 90
# Buyer 4 is assigned to Seller 11 with value 97
# Buyer 5 is assigned to Seller 12 with value 97
# Buyer 6 is assigned to Seller 10 with value 88
# Buyer 7 is assigned to Seller 7 with value 94
# Buyer 8 is assigned to Seller 3 with value 89
# Buyer 9 is assigned to Seller 13 with value 86
# Buyer 10 is assigned to Seller 18 with value 91
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x435940eb
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 619.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 920.0000000
#
# Root relaxation: objective 9.380000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     938.0000000  938.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 938 920 619
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.380000000000e+02, best bound 9.380000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 6 with value 97
# Buyer 2 is assigned to Seller 3 with value 97
# Buyer 3 is assigned to Seller 13 with value 95
# Buyer 4 is assigned to Seller 16 with value 97
# Buyer 5 is assigned to Seller 20 with value 92
# Buyer 6 is assigned to Seller 18 with value 99
# Buyer 7 is assigned to Seller 7 with value 90
# Buyer 8 is assigned to Seller 5 with value 99
# Buyer 9 is assigned to Seller 11 with value 85
# Buyer 10 is assigned to Seller 4 with value 87
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xfe0e95f2
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 495.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 920.0000000
#
# Root relaxation: objective 9.560000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     956.0000000  956.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 956 920 495
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.560000000000e+02, best bound 9.560000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 5 with value 93
# Buyer 2 is assigned to Seller 3 with value 96
# Buyer 3 is assigned to Seller 2 with value 95
# Buyer 4 is assigned to Seller 1 with value 98
# Buyer 5 is assigned to Seller 17 with value 99
# Buyer 6 is assigned to Seller 20 with value 82
# Buyer 7 is assigned to Seller 19 with value 98
# Buyer 8 is assigned to Seller 8 with value 99
# Buyer 9 is assigned to Seller 12 with value 99
# Buyer 10 is assigned to Seller 16 with value 97
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x06bb0444
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 572.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 934.0000000
#
# Root relaxation: objective 9.590000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     959.0000000  959.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 959 934 572
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 11 with value 97
# Buyer 2 is assigned to Seller 14 with value 97
# Buyer 3 is assigned to Seller 18 with value 99
# Buyer 4 is assigned to Seller 2 with value 99
# Buyer 5 is assigned to Seller 6 with value 93
# Buyer 6 is assigned to Seller 9 with value 97
# Buyer 7 is assigned to Seller 19 with value 96
# Buyer 8 is assigned to Seller 17 with value 96
# Buyer 9 is assigned to Seller 16 with value 89
# Buyer 10 is assigned to Seller 8 with value 96
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xde36101f
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 515.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 914.0000000
#
# Root relaxation: objective 9.500000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     950.0000000  950.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 950 914 515
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.500000000000e+02, best bound 9.500000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 19 with value 94
# Buyer 2 is assigned to Seller 14 with value 98
# Buyer 3 is assigned to Seller 17 with value 99
# Buyer 4 is assigned to Seller 20 with value 99
# Buyer 5 is assigned to Seller 4 with value 97
# Buyer 6 is assigned to Seller 8 with value 87
# Buyer 7 is assigned to Seller 9 with value 89
# Buyer 8 is assigned to Seller 5 with value 94
# Buyer 9 is assigned to Seller 16 with value 95
# Buyer 10 is assigned to Seller 2 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xc6c00946
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 537.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 899.0000000
#
# Root relaxation: objective 9.130000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     913.0000000  913.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 913 899 537
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.130000000000e+02, best bound 9.130000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 12 with value 92
# Buyer 2 is assigned to Seller 16 with value 81
# Buyer 3 is assigned to Seller 5 with value 99
# Buyer 4 is assigned to Seller 15 with value 97
# Buyer 5 is assigned to Seller 1 with value 88
# Buyer 6 is assigned to Seller 18 with value 84
# Buyer 7 is assigned to Seller 7 with value 98
# Buyer 8 is assigned to Seller 4 with value 93
# Buyer 9 is assigned to Seller 3 with value 91
# Buyer 10 is assigned to Seller 8 with value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x756c8dc8
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 378.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 903.0000000
#
# Root relaxation: objective 9.380000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     938.0000000  938.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 938 903 378
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.380000000000e+02, best bound 9.380000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 9 with value 97
# Buyer 2 is assigned to Seller 7 with value 80
# Buyer 3 is assigned to Seller 13 with value 99
# Buyer 4 is assigned to Seller 15 with value 90
# Buyer 5 is assigned to Seller 4 with value 90
# Buyer 6 is assigned to Seller 5 with value 99
# Buyer 7 is assigned to Seller 3 with value 92
# Buyer 8 is assigned to Seller 6 with value 95
# Buyer 9 is assigned to Seller 18 with value 99
# Buyer 10 is assigned to Seller 16 with value 97
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x42661ce4
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 496.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 910.0000000
#
# Root relaxation: objective 9.340000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     934.0000000  934.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 934 910 496
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.340000000000e+02, best bound 9.340000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 5 with value 99
# Buyer 2 is assigned to Seller 2 with value 99
# Buyer 3 is assigned to Seller 14 with value 73
# Buyer 4 is assigned to Seller 19 with value 98
# Buyer 5 is assigned to Seller 7 with value 93
# Buyer 6 is assigned to Seller 15 with value 97
# Buyer 7 is assigned to Seller 10 with value 98
# Buyer 8 is assigned to Seller 4 with value 84
# Buyer 9 is assigned to Seller 20 with value 95
# Buyer 10 is assigned to Seller 1 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x9b21464e
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 517.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 952.0000000
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 952 517
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.520000000000e+02, best bound 9.520000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 17 with value 87
# Buyer 2 is assigned to Seller 14 with value 98
# Buyer 3 is assigned to Seller 16 with value 99
# Buyer 4 is assigned to Seller 15 with value 98
# Buyer 5 is assigned to Seller 11 with value 99
# Buyer 6 is assigned to Seller 2 with value 92
# Buyer 7 is assigned to Seller 12 with value 95
# Buyer 8 is assigned to Seller 13 with value 92
# Buyer 9 is assigned to Seller 9 with value 97
# Buyer 10 is assigned to Seller 1 with value 95
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xcef8999f
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 598.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 931.0000000
#
# Root relaxation: objective 9.360000e+02, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     936.0000000  936.00000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 936 931 598
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.360000000000e+02, best bound 9.360000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 1 with value 97
# Buyer 2 is assigned to Seller 10 with value 96
# Buyer 3 is assigned to Seller 3 with value 91
# Buyer 4 is assigned to Seller 5 with value 82
# Buyer 5 is assigned to Seller 17 with value 94
# Buyer 6 is assigned to Seller 7 with value 99
# Buyer 7 is assigned to Seller 4 with value 94
# Buyer 8 is assigned to Seller 18 with value 94
# Buyer 9 is assigned to Seller 14 with value 92
# Buyer 10 is assigned to Seller 9 with value 97
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x4ea978db
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 462.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 914.0000000
#
# Root relaxation: objective 9.260000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     926.0000000  926.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 926 914 462
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.260000000000e+02, best bound 9.260000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 2 with value 96
# Buyer 2 is assigned to Seller 1 with value 92
# Buyer 3 is assigned to Seller 14 with value 79
# Buyer 4 is assigned to Seller 6 with value 96
# Buyer 5 is assigned to Seller 13 with value 98
# Buyer 6 is assigned to Seller 7 with value 99
# Buyer 7 is assigned to Seller 16 with value 87
# Buyer 8 is assigned to Seller 9 with value 90
# Buyer 9 is assigned to Seller 17 with value 91
# Buyer 10 is assigned to Seller 5 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x778a792a
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 496.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 956.0000000
#
# Root relaxation: objective 9.660000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     966.0000000  966.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 966 956 496
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.660000000000e+02, best bound 9.660000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 10 with value 97
# Buyer 2 is assigned to Seller 5 with value 98
# Buyer 3 is assigned to Seller 14 with value 98
# Buyer 4 is assigned to Seller 19 with value 93
# Buyer 5 is assigned to Seller 15 with value 99
# Buyer 6 is assigned to Seller 6 with value 97
# Buyer 7 is assigned to Seller 2 with value 99
# Buyer 8 is assigned to Seller 4 with value 96
# Buyer 9 is assigned to Seller 8 with value 91
# Buyer 10 is assigned to Seller 7 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x0001459f
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 575.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 930.0000000
#
# Root relaxation: objective 9.540000e+02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     954.0000000  954.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 954 930 575
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.540000000000e+02, best bound 9.540000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 5 with value 96
# Buyer 2 is assigned to Seller 12 with value 95
# Buyer 3 is assigned to Seller 2 with value 97
# Buyer 4 is assigned to Seller 9 with value 98
# Buyer 5 is assigned to Seller 8 with value 98
# Buyer 6 is assigned to Seller 19 with value 83
# Buyer 7 is assigned to Seller 15 with value 93
# Buyer 8 is assigned to Seller 14 with value 97
# Buyer 9 is assigned to Seller 18 with value 99
# Buyer 10 is assigned to Seller 20 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x4fc23ca7
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 548.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 896.0000000
#
# Root relaxation: objective 9.160000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     916.0000000  916.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 916 896 548
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.160000000000e+02, best bound 9.160000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 15 with value 95
# Buyer 2 is assigned to Seller 5 with value 90
# Buyer 3 is assigned to Seller 9 with value 98
# Buyer 4 is assigned to Seller 4 with value 99
# Buyer 5 is assigned to Seller 11 with value 91
# Buyer 6 is assigned to Seller 6 with value 78
# Buyer 7 is assigned to Seller 13 with value 79
# Buyer 8 is assigned to Seller 10 with value 96
# Buyer 9 is assigned to Seller 17 with value 91
# Buyer 10 is assigned to Seller 19 with value 99
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xcff9a8fc
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 475.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 902.0000000
#
# Root relaxation: objective 9.290000e+02, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     929.0000000  929.00000  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 929 902 475
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.290000000000e+02, best bound 9.290000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 5 with value 98
# Buyer 2 is assigned to Seller 7 with value 89
# Buyer 3 is assigned to Seller 20 with value 98
# Buyer 4 is assigned to Seller 16 with value 98
# Buyer 5 is assigned to Seller 17 with value 89
# Buyer 6 is assigned to Seller 8 with value 99
# Buyer 7 is assigned to Seller 9 with value 89
# Buyer 8 is assigned to Seller 19 with value 91
# Buyer 9 is assigned to Seller 15 with value 90
# Buyer 10 is assigned to Seller 1 with value 88
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xb3e0eb54
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 271.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 901.0000000
#
# Root relaxation: objective 9.050000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     905.0000000  905.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 905 901 271
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.050000000000e+02, best bound 9.050000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 20 with value 98
# Buyer 2 is assigned to Seller 9 with value 94
# Buyer 3 is assigned to Seller 14 with value 93
# Buyer 4 is assigned to Seller 8 with value 87
# Buyer 5 is assigned to Seller 12 with value 99
# Buyer 6 is assigned to Seller 10 with value 97
# Buyer 7 is assigned to Seller 17 with value 88
# Buyer 8 is assigned to Seller 6 with value 98
# Buyer 9 is assigned to Seller 5 with value 68
# Buyer 10 is assigned to Seller 4 with value 83
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x97abd04c
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 585.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 927.0000000
#
# Root relaxation: objective 9.610000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     961.0000000  961.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 961 927 585
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.610000000000e+02, best bound 9.610000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 9 with value 96
# Buyer 2 is assigned to Seller 12 with value 95
# Buyer 3 is assigned to Seller 3 with value 92
# Buyer 4 is assigned to Seller 7 with value 96
# Buyer 5 is assigned to Seller 14 with value 95
# Buyer 6 is assigned to Seller 1 with value 97
# Buyer 7 is assigned to Seller 18 with value 99
# Buyer 8 is assigned to Seller 11 with value 99
# Buyer 9 is assigned to Seller 13 with value 94
# Buyer 10 is assigned to Seller 2 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x33896f5d
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 489.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 891.0000000
#
# Root relaxation: objective 9.320000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     932.0000000  932.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 932 891 489
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.320000000000e+02, best bound 9.320000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 11 with value 95
# Buyer 2 is assigned to Seller 8 with value 93
# Buyer 3 is assigned to Seller 10 with value 98
# Buyer 4 is assigned to Seller 9 with value 93
# Buyer 5 is assigned to Seller 5 with value 92
# Buyer 6 is assigned to Seller 7 with value 87
# Buyer 7 is assigned to Seller 15 with value 93
# Buyer 8 is assigned to Seller 16 with value 94
# Buyer 9 is assigned to Seller 19 with value 92
# Buyer 10 is assigned to Seller 13 with value 95
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xbd3accf9
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 465.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 833.0000000
#
# Root relaxation: objective 9.490000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     949.0000000  949.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 949 833 465
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.490000000000e+02, best bound 9.490000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 20 with value 91
# Buyer 2 is assigned to Seller 4 with value 95
# Buyer 3 is assigned to Seller 17 with value 97
# Buyer 4 is assigned to Seller 14 with value 94
# Buyer 5 is assigned to Seller 18 with value 96
# Buyer 6 is assigned to Seller 8 with value 97
# Buyer 7 is assigned to Seller 11 with value 88
# Buyer 8 is assigned to Seller 2 with value 96
# Buyer 9 is assigned to Seller 7 with value 96
# Buyer 10 is assigned to Seller 15 with value 99
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xe9c47738
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 331.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 808.0000000
#
# Root relaxation: objective 9.110000e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     911.0000000  911.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 911 808 331
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.110000000000e+02, best bound 9.110000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 1 with value 87
# Buyer 2 is assigned to Seller 15 with value 90
# Buyer 3 is assigned to Seller 16 with value 90
# Buyer 4 is assigned to Seller 3 with value 95
# Buyer 5 is assigned to Seller 8 with value 88
# Buyer 6 is assigned to Seller 14 with value 87
# Buyer 7 is assigned to Seller 19 with value 95
# Buyer 8 is assigned to Seller 17 with value 87
# Buyer 9 is assigned to Seller 18 with value 96
# Buyer 10 is assigned to Seller 13 with value 96
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x1ea61477
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 509.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 880.0000000
#
# Root relaxation: objective 9.110000e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# ...
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 559.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 925.0000000
#
# Root relaxation: objective 9.390000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     939.0000000  939.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 939 925 559
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.390000000000e+02, best bound 9.390000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 12 with value 98
# Buyer 2 is assigned to Seller 7 with value 80
# Buyer 3 is assigned to Seller 6 with value 98
# Buyer 4 is assigned to Seller 11 with value 98
# Buyer 5 is assigned to Seller 1 with value 96
# Buyer 6 is assigned to Seller 2 with value 99
# Buyer 7 is assigned to Seller 5 with value 95
# Buyer 8 is assigned to Seller 19 with value 95
# Buyer 9 is assigned to Seller 14 with value 96
# Buyer 10 is assigned to Seller 20 with value 84
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x716867cd
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 553.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 898.0000000
#
# Root relaxation: objective 9.400000e+02, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     940.0000000  940.00000  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.16 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 940 898 553
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.400000000000e+02, best bound 9.400000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 6 with value 97
# Buyer 2 is assigned to Seller 4 with value 93
# Buyer 3 is assigned to Seller 3 with value 97
# Buyer 4 is assigned to Seller 15 with value 94
# Buyer 5 is assigned to Seller 16 with value 94
# Buyer 6 is assigned to Seller 10 with value 98
# Buyer 7 is assigned to Seller 14 with value 92
# Buyer 8 is assigned to Seller 1 with value 93
# Buyer 9 is assigned to Seller 19 with value 89
# Buyer 10 is assigned to Seller 13 with value 93
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x69c5db54
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 432.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 852.0000000
#
# Root relaxation: objective 8.990000e+02, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     899.0000000  899.00000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 899 852 432
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.990000000000e+02, best bound 8.990000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 16 with value 97
# Buyer 2 is assigned to Seller 3 with value 99
# Buyer 3 is assigned to Seller 18 with value 68
# Buyer 4 is assigned to Seller 15 with value 91
# Buyer 5 is assigned to Seller 6 with value 91
# Buyer 6 is assigned to Seller 10 with value 94
# Buyer 7 is assigned to Seller 2 with value 87
# Buyer 8 is assigned to Seller 14 with value 93
# Buyer 9 is assigned to Seller 17 with value 88
# Buyer 10 is assigned to Seller 4 with value 91
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x3a07184d
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 426.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 895.0000000
#
# Root relaxation: objective 9.320000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     932.0000000  932.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 932 895 426
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.320000000000e+02, best bound 9.320000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 1 with value 99
# Buyer 2 is assigned to Seller 5 with value 91
# Buyer 3 is assigned to Seller 13 with value 93
# Buyer 4 is assigned to Seller 16 with value 99
# Buyer 5 is assigned to Seller 4 with value 95
# Buyer 6 is assigned to Seller 17 with value 87
# Buyer 7 is assigned to Seller 14 with value 85
# Buyer 8 is assigned to Seller 10 with value 99
# Buyer 9 is assigned to Seller 6 with value 96
# Buyer 10 is assigned to Seller 18 with value 88
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x3901f258
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 522.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 945.0000000
#
# Root relaxation: objective 9.580000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     958.0000000  958.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.19 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 958 945 522
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.580000000000e+02, best bound 9.580000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 14 with value 98
# Buyer 2 is assigned to Seller 20 with value 98
# Buyer 3 is assigned to Seller 17 with value 93
# Buyer 4 is assigned to Seller 1 with value 87
# Buyer 5 is assigned to Seller 3 with value 98
# Buyer 6 is assigned to Seller 8 with value 98
# Buyer 7 is assigned to Seller 9 with value 98
# Buyer 8 is assigned to Seller 7 with value 95
# Buyer 9 is assigned to Seller 5 with value 96
# Buyer 10 is assigned to Seller 4 with value 97
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xfd055e04
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 381.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 838.0000000
#
# Root relaxation: objective 9.570000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     957.0000000  957.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 957 838 381
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.570000000000e+02, best bound 9.570000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 2 with value 96
# Buyer 2 is assigned to Seller 4 with value 94
# Buyer 3 is assigned to Seller 16 with value 90
# Buyer 4 is assigned to Seller 20 with value 93
# Buyer 5 is assigned to Seller 10 with value 99
# Buyer 6 is assigned to Seller 1 with value 98
# Buyer 7 is assigned to Seller 19 with value 97
# Buyer 8 is assigned to Seller 8 with value 95
# Buyer 9 is assigned to Seller 14 with value 97
# Buyer 10 is assigned to Seller 12 with value 98
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xac7a21fe
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 460.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 935.0000000
#
# Root relaxation: objective 9.710000e+02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     971.0000000  971.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 971 935 460
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.710000000000e+02, best bound 9.710000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 20 with value 98
# Buyer 2 is assigned to Seller 6 with value 97
# Buyer 3 is assigned to Seller 13 with value 99
# Buyer 4 is assigned to Seller 1 with value 98
# Buyer 5 is assigned to Seller 8 with value 99
# Buyer 6 is assigned to Seller 7 with value 97
# Buyer 7 is assigned to Seller 5 with value 98
# Buyer 8 is assigned to Seller 2 with value 95
# Buyer 9 is assigned to Seller 11 with value 98
# Buyer 10 is assigned to Seller 9 with value 92
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x0454776b
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 399.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 934.0000000
#
# Root relaxation: objective 9.430000e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     943.0000000  943.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 943 934 399
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.430000000000e+02, best bound 9.430000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 11 with value 92
# Buyer 2 is assigned to Seller 15 with value 98
# Buyer 3 is assigned to Seller 2 with value 93
# Buyer 4 is assigned to Seller 18 with value 99
# Buyer 5 is assigned to Seller 5 with value 90
# Buyer 6 is assigned to Seller 9 with value 99
# Buyer 7 is assigned to Seller 16 with value 83
# Buyer 8 is assigned to Seller 6 with value 95
# Buyer 9 is assigned to Seller 14 with value 97
# Buyer 10 is assigned to Seller 13 with value 97
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x65087a55
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 593.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 904.0000000
#
# Root relaxation: objective 9.450000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     945.0000000  945.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 945 904 593
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.450000000000e+02, best bound 9.450000000000e+02, gap 0.0000%
# Buyer 1 is assigned to Seller 11 with value 96
# Buyer 2 is assigned to Seller 10 with value 98
# Buyer 3 is assigned to Seller 17 with value 95
# Buyer 4 is assigned to Seller 8 with value 98
# Buyer 5 is assigned to Seller 5 with value 84
# Buyer 6 is assigned to Seller 13 with value 97
# Buyer 7 is assigned to Seller 9 with value 96
# Buyer 8 is assigned to Seller 3 with value 90
# Buyer 9 is assigned to Seller 6 with value 93
# Buyer 10 is assigned to Seller 18 with value 98

# %%
no_solution = 0
unique_solution = 0
multiple_solutions = 0

# %%
for _ in range(repeat):
  model = gp.Model("Assignment Game")
  S = np.random.randint(1, 100, size=(n, m))
  x = model.addVars(n, m, vtype=GRB.BINARY, name="x")
  model.setObjective(gp.quicksum(S[i, j] * x[i, j] for i in range(n) for j in range(m)), GRB.MAXIMIZE)
  model.addConstrs((gp.quicksum(x[i, j] for j in range(m)) <= 1 for i in range(n)), name="BuyerConstraint")
  model.addConstrs((gp.quicksum(x[i, j] for i in range(n)) <= 1 for j in range(m)), name="SellerConstraint")
  model.optimize()
  if model.status == GRB.OPTIMAL:
        solution = []
        for i in range(n):
            for j in range(m):
                if x[i, j].x == 1:  # If buyer i is assigned to seller j
                    solution.append((i, j, S[i, j]))
        model.addConstr(gp.quicksum(x[i, j] for (i, j, _) in solution) <= len(solution) - 1, name="ExcludeOriginal")
        model.optimize()

        if model.status == GRB.OPTIMAL:
            multiple_solutions += 1  # Found an alternate solution
        else:
            unique_solution += 1  # No alternate solution found
  else:
      no_solution += 1  # No feasible solution found
print(f"No solution: {no_solution}")
print(f"Unique solution: {unique_solution}")
print(f"Multiple solutions: {multiple_solutions}")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x3c577ba3
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 546.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 930.0000000
#
# Root relaxation: objective 9.450000e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     945.0000000  945.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 945 930 546
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.450000000000e+02, best bound 9.450000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0xd80a32c3
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 546.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 930.0000000
#
# Root relaxation: objective 9.440000e+02, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  944.00000    0    8  930.00000  944.00000  1.51%     -    0s
# H    0     0                     943.0000000  944.00000  0.11%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (9 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 943 930 546
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.430000000000e+02, best bound 9.430000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xac506a82
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 548.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 913.0000000
#
# Root relaxation: objective 9.350000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     935.0000000  935.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 935 913 548
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.350000000000e+02, best bound 9.350000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x356b4d0b
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 548.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 913.0000000
#
# Root relaxation: objective 9.345000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  934.50000    0    4  913.00000  934.50000  2.35%     -    0s
# H    0     0                     934.0000000  934.50000  0.05%     -    0s
#      0     0  934.50000    0    4  934.00000  934.50000  0.05%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 934 913 548
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.340000000000e+02, best bound 9.340000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x294dac0e
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 485.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 876.0000000
#
# Root relaxation: objective 9.380000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     938.0000000  938.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 938 876 485
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.380000000000e+02, best bound 9.380000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x0c84b855
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 485.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 876.0000000
#
# Root relaxation: objective 9.370000e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  937.00000    0    4  876.00000  937.00000  6.96%     -    0s
# H    0     0                     936.0000000  937.00000  0.11%     -    0s
# H    0     0                     937.0000000  937.00000  0.00%     -    0s
#      0     0  937.00000    0    4  937.00000  937.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 937 936 876 485
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.370000000000e+02, best bound 9.370000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x4b825425
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 478.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 910.0000000
#
# Root relaxation: objective 9.610000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     961.0000000  961.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 961 910 478
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.610000000000e+02, best bound 9.610000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x58fb06cf
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 478.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 910.0000000
#
# Root relaxation: objective 9.610000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     961.0000000  961.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 961 910 478
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.610000000000e+02, best bound 9.610000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xda57d9f5
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 515.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 929.0000000
#
# Root relaxation: objective 9.590000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     959.0000000  959.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 959 929 515
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0xb33cac8d
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 515.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 929.0000000
#
# Root relaxation: objective 9.585000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  958.50000    0    4  929.00000  958.50000  3.18%     -    0s
# H    0     0                     958.0000000  958.50000  0.05%     -    0s
#      0     0  958.50000    0    4  958.00000  958.50000  0.05%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 958 929 515
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.580000000000e+02, best bound 9.580000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xac85ed08
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 628.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 935.0000000
#
# Root relaxation: objective 9.460000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     946.0000000  946.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 946 935 628
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.460000000000e+02, best bound 9.460000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x1f5b04d0
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 628.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 935.0000000
#
# Root relaxation: objective 9.460000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     946.0000000  946.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 946 935 628
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.460000000000e+02, best bound 9.460000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xff32b1b1
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 540.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 921.0000000
#
# Root relaxation: objective 9.370000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     937.0000000  937.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 937 921 540
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.370000000000e+02, best bound 9.370000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0xa3326522
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 540.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 921.0000000
#
# Root relaxation: objective 9.360000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     936.0000000  936.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 936 921 540
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.360000000000e+02, best bound 9.360000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x2031a578
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 571.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 917.0000000
#
# Root relaxation: objective 9.360000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     936.0000000  936.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 936 917 571
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.360000000000e+02, best bound 9.360000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x86a2fd8a
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 571.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 917.0000000
#
# Root relaxation: objective 9.345000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  934.50000    0    4  917.00000  934.50000  1.91%     -    0s
# H    0     0                     933.0000000  934.50000  0.16%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 933 917 571
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.330000000000e+02, best bound 9.330000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x85b8b1c9
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 354.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 939.0000000
#
# Root relaxation: objective 9.410000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     941.0000000  941.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 941 939 354
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.410000000000e+02, best bound 9.410000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x9aee6f0a
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 354.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 939.0000000
#
# Root relaxation: objective 9.405000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  940.50000    0    4  939.00000  940.50000  0.16%     -    0s
# H    0     0                     940.0000000  940.50000  0.05%     -    0s
#      0     0  940.50000    0    4  940.00000  940.50000  0.05%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 940 939 354
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.400000000000e+02, best bound 9.400000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x3bba2d87
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 463.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 927.0000000
#
# Root relaxation: objective 9.390000e+02, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     939.0000000  939.00000  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 939 927 463
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.390000000000e+02, best bound 9.390000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x0e43f15b
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 463.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 927.0000000
#
# Root relaxation: objective 9.380000e+02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     938.0000000  938.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 938 927 463
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.380000000000e+02, best bound 9.380000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x83da2dfd
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 364.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 899.0000000
#
# Root relaxation: objective 9.310000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     931.0000000  931.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 931 899 364
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.310000000000e+02, best bound 9.310000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x6ac7b6d0
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 364.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 899.0000000
#
# Root relaxation: objective 9.310000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     931.0000000  931.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 931 899 364
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.310000000000e+02, best bound 9.310000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x47ae0906
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 600.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 936.0000000
#
# Root relaxation: objective 9.540000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     954.0000000  954.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 954 936 600
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.540000000000e+02, best bound 9.540000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0xf4c38702
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 600.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 936.0000000
#
# Root relaxation: objective 9.536667e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  953.66667    0    6  936.00000  953.66667  1.89%     -    0s
# H    0     0                     952.0000000  953.66667  0.18%     -    0s
# H    0     0                     953.0000000  953.66667  0.07%     -    0s
#      0     0  953.66667    0    6  953.00000  953.66667  0.07%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 953 952 936 600
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.530000000000e+02, best bound 9.530000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x6253120c
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 390.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 915.0000000
#
# Root relaxation: objective 9.160000e+02, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     916.0000000  916.00000  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 916 915 390
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.160000000000e+02, best bound 9.160000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x120813a0
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 390.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 915.0000000
#
# Root relaxation: objective 9.160000e+02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     916.0000000  916.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 916 915 390
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.160000000000e+02, best bound 9.160000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x94f69ea2
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 492.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 906.0000000
#
# Root relaxation: objective 9.150000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     915.0000000  915.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 915 906 492
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.150000000000e+02, best bound 9.150000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0xfaa0bba7
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 492.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 906.0000000
#
# Root relaxation: objective 9.143333e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  914.33333    0    6  906.00000  914.33333  0.92%     -    0s
# H    0     0                     913.0000000  914.33333  0.15%     -    0s
# H    0     0                     914.0000000  914.33333  0.04%     -    0s
#      0     0  914.33333    0    6  914.00000  914.33333  0.04%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.14 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 914 913 906 492
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.140000000000e+02, best bound 9.140000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x8b6b6f94
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 401.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 949.0000000
#
# Root relaxation: objective 9.610000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     961.0000000  961.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 961 949 401
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.610000000000e+02, best bound 9.610000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0xb8dac2d2
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 401.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 949.0000000
#
# Root relaxation: objective 9.600000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     960.0000000  960.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 960 949 401
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.600000000000e+02, best bound 9.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x7114d80a
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 429.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 943.0000000
#
# Root relaxation: objective 9.470000e+02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     947.0000000  947.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.17 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 947 943 429
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.470000000000e+02, best bound 9.470000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x1bd0c4d8
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 429.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 943.0000000
#
# Root relaxation: objective 9.470000e+02, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     947.0000000  947.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.23 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 947 943 429
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.470000000000e+02, best bound 9.470000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x14cb52a0
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 395.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 954.0000000
#
# Root relaxation: objective 9.630000e+02, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# ...
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0xb208a0d5
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 564.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 926.0000000
#
# Root relaxation: objective 9.610000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  961.00000    0    4  926.00000  961.00000  3.78%     -    0s
# H    0     0                     959.0000000  961.00000  0.21%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.40 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 959 926 564
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.590000000000e+02, best bound 9.590000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x50e0400b
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 403.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 918.0000000
#
# Root relaxation: objective 9.370000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     937.0000000  937.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 937 918 403
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.370000000000e+02, best bound 9.370000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x16e47083
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 403.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 918.0000000
#
# Root relaxation: objective 9.366667e+02, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  936.66667    0    6  918.00000  936.66667  2.03%     -    0s
# H    0     0                     936.0000000  936.66667  0.07%     -    0s
#      0     0  936.66667    0    6  936.00000  936.66667  0.07%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 936 918 403
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.360000000000e+02, best bound 9.360000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x895c718a
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 650.0000000
# Presolve time: 0.01s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 910.0000000
#
# Root relaxation: objective 9.540000e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     954.0000000  954.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 954 910 650
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.540000000000e+02, best bound 9.540000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x0105fc0a
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 650.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 910.0000000
#
# Root relaxation: objective 9.540000e+02, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     954.0000000  954.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 954 910 650
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.540000000000e+02, best bound 9.540000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xa1d216cb
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 444.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 956.0000000
#
# Root relaxation: objective 9.710000e+02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     971.0000000  971.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 971 956 444
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.710000000000e+02, best bound 9.710000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0xd2c8e0cc
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 444.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 956.0000000
#
# Root relaxation: objective 9.710000e+02, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     971.0000000  971.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 971 956 444
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.710000000000e+02, best bound 9.710000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x0ac100b5
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 475.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 877.0000000
#
# Root relaxation: objective 9.160000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     916.0000000  916.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 916 877 475
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.160000000000e+02, best bound 9.160000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x4b235cf8
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 475.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 877.0000000
#
# Root relaxation: objective 9.150000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     915.0000000  915.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 915 877 475
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.150000000000e+02, best bound 9.150000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 30 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0x84b620d0
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 537.0000000
# Presolve time: 0.00s
# Presolved: 30 rows, 200 columns, 400 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 922.0000000
#
# Root relaxation: objective 9.440000e+02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     944.0000000  944.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 944 922 537
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.440000000000e+02, best bound 9.440000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 31 rows, 200 columns and 410 nonzeros
# Model fingerprint: 0x1969aea7
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint ExcludeOriginal by 1.000000000
#
# Found heuristic solution: objective 537.0000000
# Presolve time: 0.00s
# Presolved: 31 rows, 200 columns, 410 nonzeros
# Variable types: 0 continuous, 200 integer (200 binary)
# Found heuristic solution: objective 922.0000000
#
# Root relaxation: objective 9.430000e+02, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     943.0000000  943.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 943 922 537
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.430000000000e+02, best bound 9.430000000000e+02, gap 0.0000%
# No solution: 0
# Unique solution: 0
# Multiple solutions: 50
